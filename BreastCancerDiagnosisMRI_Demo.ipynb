# %%
# !rm -rf BreastCancerDiagnosisMRI
# !git clone -b develop https://github.com/lkshrsch/BreastCancerDiagnosisMRI.git

# !pip install tensorflow==2.17
# Out:
# Cloning into 'BreastCancerDiagnosisMRI'...
# fatal: Remote branch develop not found in upstream origin
# ...

# %%
import tensorflow as tf
print(tf.__version__)

# %run Make_Prediction_on_MRI.py
# Out:
# 2.17.0
# resampling to a resolution of 0.4 x 0.4mm..
# cropping/padding to size 512 x 512 pixels..
# Data preprocessed.. model inference
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757534583.381112  203032 service.cc:146] XLA service 0x7f9794014600 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1757534583.381136  203032 service.cc:154]   StreamExecutor device (0): NVIDIA L40, Compute Capability 8.9
# I0000 00:00:1757534583.381140  203032 service.cc:154]   StreamExecutor device (1): NVIDIA L40S, Compute Capability 8.9
# I0000 00:00:1757534583.381142  203032 service.cc:154]   StreamExecutor device (2): NVIDIA L40, Compute Capability 8.9
# I0000 00:00:1757534583.381145  203032 service.cc:154]   StreamExecutor device (3): NVIDIA L40, Compute Capability 8.9
# ...

# %%
import pandas as pd 

labels = pd.read_csv('/mnt/shareddata/users/joyliu/current/ReportAnalysis/converted_volumes/info/train_with_path_v5.csv')
# Out:
# /tmp/ipykernel_202687/3620878844.py:3: DtypeWarning: Columns (0,14,25,27,63,86,206) have mixed types. Specify dtype option on import or set low_memory=False.
#   labels = pd.read_csv('/mnt/shareddata/users/joyliu/current/ReportAnalysis/converted_volumes/info/train_with_path_v5.csv')

# %%
labels[labels['sample_name'] == 11581013]['year_0']
# Out:
# 7310    1.0
# Name: year_0, dtype: float64

# %%
val_labels = pd.read_csv('/mnt/shareddata/users/joyliu/current/ReportAnalysis/converted_volumes/info/val_with_path_v5.csv')

# %%
list(val_labels.columns)
# Out:
# ['sample_name',
#  'main_series',
#  'series',
#  'captions',
#  'main_img_path',
#  'img_paths',
#  'Orig Patient Name',
#  'Anon Patient Name',
#  'Orig MRN',
#  'Anon MRN',
#  'Orig Sex',
#  'Anon Sex',
#  'Orig DOB',
#  'Anon DOB',
#  'Orig Acc #',
#  'Anon Acc #',
#  'Orig Exam Date/Time',
#  'Anon Exam Date/Time',
#  'Orig Exam Description',
#  'Anon Exam Description',
#  'Orig Study UID',
#  'Anon Study UID',
#  '# Retrieved',
#  '# Anonymized',
#  'study_path',
#  'accession',
#  'Unnamed: 0',
#  'Image Req. Status',
#  'Bytes Retrieved',
#  'Bytes Anonymized',
#  '# Transferred',
#  'Bytes Transferred',
#  'no_report',
#  'complete',
#  'gt_Breast Extent of Disease_Mass',
#  'gt_Breast Extent of Disease_Tumor size measurement',
#  'gt_Breast Extent of Disease_Non-mass enhancement',
#  'gt_Breast Extent of Disease_Multifocal disease',
#  'gt_Breast Extent of Disease_Multicentric disease',
#  'gt_Breast Extent of Disease_Unifocal disease',
# ...

# %%
mri_studies =
