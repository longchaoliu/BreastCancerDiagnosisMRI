# %%
# !rm -rf BreastCancerDiagnosisMRI
# !git clone -b develop https://github.com/lkshrsch/BreastCancerDiagnosisMRI.git

#!pip install tensorflow==2.17
# Out:
# Cloning into 'BreastCancerDiagnosisMRI'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 266 (delta 60), reused 140 (delta 38), pack-reused 89 (from 1)
# Receiving objects: 100% (266/266), 195.71 MiB | 28.13 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# Updating files: 100% (12/12), done.

# %%
# Out:
# ...
#   Using cached tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# ...
# Using cached tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 14.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.1
#     Uninstalling tensorflow-2.16.1:
#       Successfully uninstalled tensorflow-2.16.1
# ...

# %%
import tensorflow as tf
print(tf.__version__)

# %run BreastCancerDiagnosisMRI/Make_Prediction_on_MRI.py
# Out:
# 2.17.0
# resampling to a resolution of 0.4 x 0.4mm..
# cropping/padding to size 512 x 512 pixels..
# Data preprocessed.. model inference
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor', 'keras_tensor_45']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step
# prediction done..
# Generating gradCAM heatmap..
